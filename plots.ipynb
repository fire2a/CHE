# %%
from main import CHE, intersection

import numpy as np
import pandas as pd
from plot import plot3D_convexhulls
import os

# %%
IN_FOLDER = 'data'
d_fn = os.path.join(IN_FOLDER, 'D.csv')
b_bar = pd.read_csv(d_fn, usecols = ['Bbar', 'Eisa'])

pcs_fn = os.path.join(IN_FOLDER, 'TablaPCs.csv')
# Visual Python: Data Analysis > File
pcs = pd.read_csv(pcs_fn, sep = ' ', 
                    usecols = ['PC1', 'PC2', 'PC3', 
                            #    'PC4'
                               ]
                               )

# convert dataframe to arrays
data = pd.concat([b_bar, pcs], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6169 entries, 0 to 6168
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Bbar    6169 non-null   int64
#  1   Eisa    6169 non-null   int64
#  2   PC1     6169 non-null   float64
#  3   PC2     6169 non-null   float64
#  4   PC3     6169 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 241.1 KB

# %%
Bbar = CHE(data.query('Bbar == 1')[['Bbar','PC1', 'PC2', 'PC3']])
Bbar.cov()

Eisa = CHE(data.query('Eisa == 1')[['PC1', 'PC2', 'PC3']])
Eisa.cov()

ches = [Bbar, Eisa]

Inte = intersection(ches)

Bbar.species
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 Bbar = CHE(data.query('Bbar == 1')[['Bbar','PC1', 'PC2', 'PC3']])
# ----> 2 Bbar.cov()
#       4 Eisa = CHE(data.query('Eisa == 1')[['PC1', 'PC2', 'PC3']])
#       5 Eisa.cov()
#
# File ~/Documentos/GitHub/CHE/main.py:72, in CHE.cov(self, p, list_var)
#      69 points = points.to_numpy()
#      70 d = points.shape[1]
# ---> 72 ellip = EllipticEnvelope(points, 'COV', p)
#      74 pred = ellip.contains(points)
#      75 pred[pred == -1] = 0
#
# File ~/Documentos/GitHub/CHE/tools.py:52, in EllipticEnvelope.__init__(self, X, model, p)
#      50 self.X = X
#      51 self.model = model
# ---> 52 self.A, self.c = elliptic_envelope(X, model, p)
#      53 self.volume = vol_ellipsoid(self.A)
#
# File ~/Documentos/GitHub/CHE/tools.py:31, in elliptic_envelope(X, model, p)
#      28     cov1 = np.cov(X.T)
# ...

# %%
plot3D_convexhulls([Bbar, Eisa])

# %%
plot3D_convexhulls([Bbar, Eisa, Inte])
